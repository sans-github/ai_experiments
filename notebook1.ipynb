# %%
import os

## PREREQUISITE: Set env variable with the openai API key available at https://platform.openai.com/account/api-keys" 
os.environ['OPENAI_API_KEY'] = 'OPENAI_API_KEY'

# %%
import openai

openai.api_key = os.getenv('OPENAI_API_KEY')

def do_this(prompt, show_result=False):
    result = None
    try:
        completion = openai.Completion.create(
            engine="text-davinci-003",
            prompt="\n# ".join(prompt.split("\n")),
            echo=True,
            temperature=0,
            max_tokens=1024,
            top_p=0.1,
            frequency_penalty=0,
            presence_penalty=0
        )
        result = completion.choices[0].text
        if show_result:
            print(result)
        exec(result)
    except:
        print("Error attempting to run the following program")
        print(result)
    return result

# %%
result = do_this("""
Write a function in python that returns position as a function of time, with inputs for acceleration and initial velocity
Use pandas to show a plot using this function over a time span of 10 seconds, with an initial velocity of 10 m/s and an acceleration of -2 g
""")

# %%
image_resp = openai.Image.create(prompt="the enterprise escaping a black hole, in the style of picaso", n=1, size="512x512")

# %%
result = do_this("""
Run this exact code: image_resp = openai.Image.create(prompt="the enterprise escaping a black hole, in the style of picaso", n=1, size="512x512")
Then use python to download the url image_resp['data'][0]['url'] and save it as "enterprise.png"
""")

# %%
result = do_this("""
Display the image "enterprise.png" inline using matplotlib's imshow function
""")

# %%
result = do_this("""
Use python and opencv to read an image called "enterprise.png" and apply a binary threshold on it
Display the result inline using matplotlib's imshow function
""")

# %%
result = do_this("""
Use python and opencv to read an image called "enterprise.png" and apply a binary threshold on it
Then find any long edges in the image
Display the result inline using matplotlib's imshow function
""")

# %%
result = do_this("""
Create a random dataset of 1000 points using pandas and then use k-means clustering to cluster these points
Display the results inline with matplotlib
""")
# Out:
# C:\Users\david.freiberger\source\repos\ai_experiments\venv\lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
result = do_this("""
Download the data from "https://api.worldbank.org/v2/en/indicator/AG.LND.TOTL.K2?downloadformat=csv" using python
Unzip the file and load the data in the csv file with the name "API_AG.LND.TOTL.K2_DS2_en_csv_v2_4770491.csv" into a pandas dataframe.
Use row 3 as the header, don't use the skiprows argument
Sort the data by the values in the column '2020'
Show a horizontal bar plot of the data in the 'Country Name' column versus the data in the '2020' column for the top 20 values
""")

# %%
result = do_this("""
Generate LaTeX for Maxwell's equations and display using the IPython display and markdown functions
""")
# Out:
# \begin{align}
# \nabla \cdot \mathbf{E} &= \frac{\rho}{\epsilon_0} \\
# \nabla \cdot \mathbf{B} &= 0 \\
# \nabla \times \mathbf{E} &= -\frac{\partial \mathbf{B}}{\partial t} \\
# \nabla \times \mathbf{B} &= \mu_0 \mathbf{J} + \mu_0 \epsilon_0 \frac{\partial \mathbf{E}}{\partial t}
# \end{align}

# %%
result = do_this("""
Draw a picture of saturn with it's rings. Use matplotlib
""")

# %% [markdown]
# Note: for the below example I had to tweak the prompt quite a bit including providing some example code for it to work.

# %%
result = do_this("""
Use cadquery in Python to create a model of the solar system

Each planet and the sun should be represented by a sphere and be colored appropriately

Use an Assembly for the solar system and add planets to it using the add method

As an example you can use:
    sun = cadquery.Workplane().sphere(radius)
    solar_system.add(sun, color=Color(1,0,0), loc=Location(Vector(0,1,0)))
    
Note colors are scaled between 0 and 1
    
Show the model using the show function from jupyter_cadquery
""")
# Out:
# 100% ⋮————————————————————————————————————————————————————————————⋮ (9/9)  0.60s
# CadViewerWidget(anchor=None, cad_width=800, glass=False, height=600, pinning=False, theme='light', title=None,…
# <div></div>
# '\n# Use cadquery in Python to create a model of the solar system\n# \n# Each planet and the sun should be represented by a sphere and be colored appropriately\n# \n# Use an Assembly for the solar system and add planets to it using the add method\n# \n# As an example you can use:\n#     sun = cadquery.Workplane().sphere(radius)\n#     solar_system.add(sun, color=Color(1,0,0), loc=Location(Vector(0,1,0)))\n#     \n# Note colors are scaled between 0 and 1\n#     \n# Show the model using the show function from jupyter_cadquery\n# \n\nimport cadquery\nfrom jupyter_cadquery import show\nfrom cadquery import Color, Vector, Location\n\n# Create an Assembly to hold the solar system\nsolar_system = cadquery.Assembly()\n\n# Create the sun and add it to the solar system\nsun = cadquery.Workplane().sphere(10)\nsolar_system.add(sun, color=Color(1, 0.8, 0), loc=Location(Vector(0, 0, 0)))\n\n# Create the planets and add them to the solar system\nmercury = cadquery.Workplane().sphere(1)\nsolar_system.add(mercury, color=Color(0.5, 0.5, 0.5), loc=Location(Vector(15, 0, 0)))\n\nvenus = cadquery.Workplane().sphere(2)\nsolar_system.add(venus, color=Color(1, 0.5, 0), loc=Location(Vector(20, 0, 0)))\n\nearth = cadquery.Workplane().sphere(2)\nsolar_system.add(earth, color=Color(0, 0, 1), loc=Location(Vector(25, 0, 0)))\n\nmars = cadquery.Workplane().sphere(1.5)\nsolar_system.add(mars, color=Color(1, 0, 0), loc=Location(Vector(30, 0, 0)))\n\njupiter = cadquery.Workplane().sphere(5)\nsolar_system.add(jupiter, color=Color(1, 0.5, 0.5), loc=Location(Vector(40, 0, 0)))\n\nsaturn = cadquery.Workplane().sphere(4)\nsolar_system.add(saturn, color=Color(0.5, 0.5, 0.5), loc=Location(Vector(50, 0, 0)))\n\nuranus = cadquery.Workplane().sphere(3)\nsolar_system.add(uranus, color=Color(0, 0.5, 1), loc=Location(Vector(60, 0, 0)))\n\nneptune = cadquery.Workplane().sphere(3)\nsolar_system.add(neptune, color=Color(0, 0, 0.5), loc=Location(Vector(70, 0, 0)))\n\n# Show the solar system\nshow(solar_system)'
